# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting yfinance==0.1.64 (from -r ./requirements.txt (line 1))
#   Downloading yfinance-0.1.64.tar.gz (26 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=0.24 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from yfinance==0.1.64->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: numpy>=1.15 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from yfinance==0.1.64->-r ./requirements.txt (line 1)) (1.26.1)
# Requirement already satisfied: requests>=2.20 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from yfinance==0.1.64->-r ./requirements.txt (line 1)) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance==0.1.64->-r ./requirements.txt (line 1))
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.5.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from yfinance==0.1.64->-r ./requirements.txt (line 1)) (4.9.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from pandas>=0.24->yfinance==0.1.64->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pandas>=0.24->yfinance==0.1.64->-r ./requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests>=2.20->yfinance==0.1.64->-r ./requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from requests>=2.20->yfinance==0.1.64->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests>=2.20->yfinance==0.1.64->-r ./requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests>=2.20->yfinance==0.1.64->-r ./requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance==0.1.64->-r ./requirements.txt (line 1)) (1.16.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py): started
#   Building wheel for yfinance (setup.py): finished with status 'done'
#   Created wheel for yfinance: filename=yfinance-0.1.64-py2.py3-none-any.whl size=24105 sha256=e91ebc4c30eb90e69b8edab44881ee75ca803ef39917f2f4937bdb3e0299ce15
#   Stored in directory: /root/.cache/pip/wheels/18/de/bf/bf32a79618de829ca590fca5bf7142b79367cae0944a2ca12e
# Successfully built yfinance
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.11 yfinance-0.1.64
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
